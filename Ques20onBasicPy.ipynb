# %%
# Perfect! Here’s a **20-question Python quiz** covering data types, dictionary, tuple, list, string, loops, lambda, recursion, and file handling.  

# ---

# ## 🐍 Python Quiz (20 Questions)

# ### **Data Types & Basics**
# 1. What is the output of `type(3.14)` in Python? 
#Ans. The output of type(3.14) is in python (float)

# 2. Which of the following is **immutable**: List, Tuple, Dictionary, Set? 
#Ans. 

# 3. What is the default data type of `input()` function’s return value?  
# Ans. String

# 4. How do you check the length of a string in Python?
#str.len

# ### **Lists & Tuples**
# 5. What will be the output of:  
#    ```python
#    my_list = [1, 2, 3]
#    print(my_list[1])
#    ```  
# 6. Which method is used to add an element at the end of a list?  
# 7. What is the difference between a list and a tuple in Python?  
# 8. What will be the result of:  
#    ```python
#    my_tuple = (10, 20, 30)
#    print(my_tuple[0])
#    ```  

# ### **Dictionary**
# 9. How do you access the value of key `"name"` in this dictionary?  
#    ```python
#    student = {"name": "Ajay", "age": 21}
#    ```  
# 10. Which method is used to get all keys of a dictionary?  
# 11. What happens if you try to access a non-existing key directly in a dictionary?  

# ### **Strings**
# 12. What will be the output of:  
#    ```python
#    s = "Python"
#    print(s.upper())
#    ```  
# 13. How do you check if a substring exists inside a string?  
# 14. What is the difference between `isalpha()` and `isdigit()` methods?  

# ### **Loops**
# 15. What will be the output of:  
#    ```python
#    for i in range(3):
#        print(i)
#    ```  
# 16. Which loop is used when the number of iterations is **unknown**?  

# ### **Lambda & Functions**
# 17. Write a lambda function to add two numbers.  

# 18. What is the difference between a normal function and a lambda function?  

# ### **Recursion**
# 19. What is recursion in Python?  
# 20. Write a simple recursive function to calculate factorial of a number.
