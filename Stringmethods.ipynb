# %%
t=list((1,4,5,6,7,8,9,5,5.24,"tom",7-5j,2))
t
# Out:
# [1, 4, 5, 6, 7, 8, 9, 5, 5.24, 'tom', (7-5j), 2]

# %%
len(t)
# Out:
# 9

# %%
type(t)
# Out:
# list

# %%
t[-1]
# Out:
# 2

# %%
t[-2]
# Out:
# (7-5j)

# %%
t[1:4]
# Out:
# [4, 5, 6]

# %%
t[1:4]=["rohit","sharma",2,53,5,3]
t
# Out:
# [1,
#  'rohit',
#  'sharma',
#  2,
#  53,
#  5,
#  3,
#  53,
#  5,
#  3,
#  53,
#  5,
#  3,
#  7,
#  8,
#  9,
#  5,
#  5.24,
#  'tom',
#  (7-5j),
#  2]

# %%
# adding elemetn without replaicing 
t.insert(1,"gulsan")
t
# Out:
# [1,
#  'gulsan',
#  'rohit',
#  'sharma',
#  2,
#  53,
#  5,
#  3,
#  53,
#  5,
#  3,
#  53,
#  5,
#  3,
#  7,
#  8,
#  9,
#  5,
#  5.24,
#  'tom',
#  (7-5j),
#  2]

# %%
del t[1:2]
t
# Out:
# ['gulsan',
#  'sharma',
#  2,
#  53,
#  5,
#  3,
#  53,
#  5,
#  3,
#  53,
#  5,
#  3,
#  7,
#  8,
#  9,
#  5,
#  5.24,
#  'tom',
#  (7-5j),
#  2]

# %%
t
# Out:
# ['gulsan',
#  'rohit',
#  'sharma',
#  2,
#  53,
#  5,
#  3,
#  53,
#  5,
#  3,
#  53,
#  5,
#  3,
#  7,
#  8,
#  9,
#  5,
#  5.24,
#  'tom',
#  (7-5j),
#  2]

# %%
t.remove(53)
t
# Out:
# ['gulsan',
#  'sharma',
#  2,
#  5,
#  3,
#  5,
#  3,
#  53,
#  5,
#  3,
#  7,
#  8,
#  9,
#  5,
#  5.24,
#  'tom',
#  (7-5j),
#  2]

# %% [raw]
# sum(s)

# %%
s=[45,46,6,34,44,56]
s.reverse()

# %%
s=[45,46,6,34,44,56]
s.sort(reverse=ture)
s
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[37], line 2
#       1 s=[45,46,6,34,44,56]
# ----> 2 s.sort(reverse=ture)
#       3 s
#
# NameError: name 'ture' is not defined

# %%
# TUPLE

# %%
s=tuple((4,5,'rohi',9+5j,34.34,True))
s
# Out:
# (4, 5, 'rohi', (9+5j), 34.34, True)
