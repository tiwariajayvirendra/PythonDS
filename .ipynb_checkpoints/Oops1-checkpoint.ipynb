# %%
#Gulsan Sir , 

# Principles Of OOPS Encapsulation , and Inheritence , and Abstraction and Polymorphysm,

#Encapsulation 

#kuch attributes ya features ko hide karna hai aur kuch features ko show karna hai , isme 3 use hote hain public and private and protactive, atttribute,
#Public is anywhere in class out or class in
#Protected ,= is under only ,
# Private is alwayes only class in 
#Enc that restricts direct access to some of an objects attributes and methods. this done to p
#Protect the integrity of the objects's data and to prevent unintended interference.
#Data Hiding  e allows you to hide the internal state of an object You can control access to 
#cetrain 

# a = 5  // Public  we can access, outside the class,
# _a = 5 // Protected // but can't be acces it out of the class
# __a=5 // Private // but it is highly protected but not accessible from outside .

class a:
    _s=20 #Protected 
    __b=30#Private

    def show(self):
        print("Protected inside class:",self._s)
        print("Private inside clas
        s :",self.__b)
obj=a()
obj.show()
# Out:
#   Cell In[6], line 26
#     print("Private inside clas
#           ^
# SyntaxError: unterminated string literal (detected at line 26)

# %%
class a:
    _s=20 #Protected 
    __b=30 #Private

    def show(self):
        print("protected Inside class:",self._s)
        print("Private inside class :",self.__b)
obj=a()
obj.show()
print("outside of the class :", obj._s)#We can access protected variable outside of the class .
# Out:
# protected Inside class: 20
# Private inside class : 30
# outside of the class : 20

# %%
class Employee:
    _employee_id = 101 #Protected Attribute
    __salary = 500000 # Private attr

    def __init__(self,name):
        self.name = name #public attri
    def show_details(self):
        #Accessing both protected and private attributes inside the class 
        print("name:",self.name)
        print("Protected Employee ID inside class",self._employee_id)
        print("private salary inside class: ",self._salary)

    def give_raise(self,amount):
        if amount > 0:
            self.__salary += amount
            print(f"salary updated to :{self.__salary}")
        else:
            print("Raise amount moust be positive")
#Create an object of the employee class

emp = Employee("Ajay Tiwari")
emp.show_details()
emp.give_raise(9000)
emp.show_details()
# Out:
# name: Ajay Tiwari
# Protected Employee ID inside class 101
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 22
#      19 #Create an object of the employee class
#      21 emp = Employee("Ajay Tiwari")
# ---> 22 emp.show_details()
#      23 emp.give_raise(9000)
#      24 emp.show_details()
#
# Cell In[14], line 11, in Employee.show_details(self)
#       9 print("name:",self.name)
#      10 print("Protected Employee ID inside class",self._employee_id)
# ---> 11 print("private salary inside class: ",self._salary)
#
# AttributeError: 'Employee' object has no attribute '_salary'

# %%
class a :
    _s=20 #Private,
    __b=30#Private

    def show(self):
        print("Protected inside class :",self._s)
        print("Private inside class " ,self.__b)

# %%
class a:
    _s=20 #P
    __b=30 #Private

    def show(self):
        print("Protetedinside class ",self._s)
        print("Privatee inside class",self.__b)
obj=a()
obj.show()
print("outside of class access bu class:",a._s)
print('outside of class access by ',a.__b)
# Out:
# Protetedinside class  20
# Privatee inside class 30
# outside of class access bu class: 20
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 11
#       9 obj.show()
#      10 print("outside of class access bu class:",a._s)
# ---> 11 print('outside of class access by ',a.__b)
#
# AttributeError: type object 'a' has no attribute '__b'

# %%
#Create a class Google Pay In which information of diffrent account holders are given also information such as
#there UPI Bin , There bank Account Name, Total balance , are given , I need to access balance,and bank name of any indivisual account holder.
class GooglePay:
    def __init__(self, name, upi_bin, bank_name, balance):
        # Private attributes (encapsulation)
        self.name = name
        self.__upi_pin = upi_pin
        self._bank_name = bank_name
        self.__balance = balance

    # Getter methods to access private data
    def get_bank_name(self):
        return self._bank_name

    def get_balance(self):
        return self.__balance

    # Optional: method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"{amount} deposited successfully.")
        else:
            print("Invalid deposit amount.")

    # Optional: method to withdraw money
    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"{amount} withdrawn successfully.")
        else:
            print("Insufficient balance or invalid amount.")

# -------------------------------
# Example usage
account1 = GooglePay("Rahul", "UPI1234", "HDFC Bank", 5000)
account2 = GooglePay("Priya", "UPI5678", "ICICI Bank", 8000)

print("Rahul's Bank:", account1.get_bank_name())
print("Rahul's Balance:", account1.get_balance())

print("Priya's Bank:", account2.get_bank_name())
print("Priya's Balance:", account2.get_balance())

# Deposit and Withdraw
account1.deposit(2000)
print("Rahul's Updated Balance:", account1.get_balance())

account2.withdraw(3000)
print("Priya's Updated Balance:", account2.get_balance())
# Out:
# Rahul's Bank: HDFC Bank
# Rahul's Balance: 5000
# Priya's Bank: ICICI Bank
# Priya's Balance: 8000
# 2000 deposited successfully.
# Rahul's Updated Balance: 7000
# 3000 withdrawn successfully.
# Priya's Updated Balance: 5000
