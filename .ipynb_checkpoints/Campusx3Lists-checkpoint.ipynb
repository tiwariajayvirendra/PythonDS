# %%
#Session 4 -Python - Lists by campus x Data science Mentorship Program 
#What are Lists
#List is a data type where you can stroe multiple item under 1 name. More technically, 
#Lists are act like dynamic arrays which means you can add more items on the fly.

# l[ A, B, C, D, E, F ]
#Array vs List
#Arrays 
# Reffrencial Array , or pointer or address storing ,
L = [1,2,3]
b= 2
print(id(L),"arr")
print(id(L[0]))
print(id(L[1]))
print(id(L[2]))
print(id(1))
print(id(2))
print(id(3))
# Out:
# 1962513813440 arr
# 140723123561592
# 140723123561624
# 140723123561656
# 140723123561592
# 140723123561624
# 140723123561656

# %%
#Characteristcs of a list 
# Lists are Ordered 
#Ordered 
#Changeble/Mutable
#Can Have duplicates
#are dynamic
#can be Nested
#Items can be accessed
#can contain any kind of Objectes in python 
#

# %%
#Ordered
L = [1,2,3]
L1 = [3,2,1]
L == L1
# Out:
# False

# %%
#Changeble / Mutable
# wer are change in List so it is mutable.

# %%
#Hetrogeneous List
L= [20,"jessa",43.44,[3,4,5]]

# %%
#Can have dubplicates
L = [1,2,3,4]
L1 = [3,2,1]

# %%
# Can be Nested
L= [20,"jessa",43.44,[3,4,5]]

# %%
#Items can be accessed

# %%
#Can contain anh kind of objects in python
