# %%
#Every Thing is An Object in Python like string
# 
# class Atm:
#     #Punction vs Methods  // MEthods is  a special function to use it only used by its class objects .
#     def_init_(self):
    
    
#     self.pin=''
#     self.balance = 0 

#     self.menu()
class Atm:
    def_init_(self):
    self.pin= ""
    self.balance = 0
    self.menu()

    def
# Out:
#   Cell In[1], line 13
#     def_init_(self):
#                    ^
# SyntaxError: invalid syntax

# %%
#createing class
class Student:
    name = "Karan"
#Createing Objects

s1= Student()
print(s1.name)

s2 = Student()
print(s2.name)
# Out:
# Karan
# Karan

# %%
class Car :
    color = "blue"
    brand = "Mercideice"

car1= Car()
print(car1.color)
print(car1.brand)
# Out:
# blue
# Mercideice

# %%
#Class Constructor 

class Student:
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks
        print("Adding New student in database..")
s1 = Student("Karan",88)
print(s1.name,s1.marks)

s2=Student("Arjun",34)
print(s2.name,s2.marks)
# Out:
# Adding New student in database..
# Karan 88
# Adding New student in database..
# Arjun 34

# %%
#Attributes

#Anyy data 

#we have 2 types first (class.attr)
#2  -obj.attr

class Student:
    collage_name = "Abc collage"
    
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks
        print("Adding New student in database..")
s1 = Student("Karan",88)
s1.welcome(43,948948)
print(s1.age,s1.number)
# Out:
# Adding New student in database..
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 16
#      14         print("Adding New student in database..")
#      15 s1 = Student("Karan",88)
# ---> 16 s1.welcome(43,948948)
#      17 print(s1.age,s1.number)
#
# AttributeError: 'Student' object has no attribute 'welcome'

# %%
#Methods 
#Methods are functin that belongt to objects.


class Student:
    collage_name="AbC Collage"
    
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks
        print("Adding New student in database..")
        
    def welcome(self,age, number):
        self.age = age
        self.number = number
        print("Adding Age and Number ")
        
# s1 = Student("Karan",88)
# print(s1.name,s1.marks)

# s2=Student("Arjun",34)
# print(s2.name,s2.marks)

s1 = Student("karan",77)
s1.welcome(44,534544)
print(s1.age,s1.number)
# Out:
# Adding New student in database..
# Adding Age and Number
# 44 534544

# %%
#Gulsan Sir Teaching

# %%
#Exception Handeling 
#Try  - Recognizing find Error  or Exception error
#Except - Resolve error
#Else- pertercularly error na ho to  
#Finally- aur jab error ho
# Out:
# Enter Your value 30
# Hii

# %%
q = "rohan
print(q)

#index error bhi hota hai
# Out:
#   Cell In[9], line 1
#     q = "rohan
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
numerator = 10 
denominator = 0
result = numerator/ denominator
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 numerator = 10
#       2 denominator = 0
# ----> 3 result = numerator/ denominator
#       4 print(result)
#
# ZeroDivisionError: division by zero

# %%
a = {1,2,3,4,5,6}
v{10}
print(a)
# Out:
#   Cell In[15], line 2
#     v{10}
#      ^
# SyntaxError: invalid syntax

# %%
x = "gulsahan"
x[0:15]
# Out:
# 'gulsahan'

# %%
try:
    a = [2,4,6,9]
    print(a[5])
except ZeroDivisionError:
    print("index otu of Bound")
except IndexError:
    print("index out of Bound")
# Out:
# index out of Bound

# %%
try :
    x = int(input("enter a Number;"))
    result =10 / x
    print(result)
except(zeroDivisionError, valueError) as e:
    print(f"An error Occoured:{e}")
else:
    print("division ok")
# Out:
# enter a Number; 5
# 2.0
# division ok

# %%
def error_removle(x):
    try:
        x=int(input("enter any num"))
        result = 10/x
    except Exception as e:
        print(f"an error occured:{e}")
    else:
        print("division OL")
error_removle(5)
error_removle(0)
error_removle("tom")
error_removle(5+4j)
# Out:
# enter any num 5
# division OL
# enter any num 6
# division OL
# enter any num w
# an error occured:invalid literal for int() with base 10: 'w'
# enter any num 5
# division OL

# %%
import builtins
for e in dir(builtins):
    if
