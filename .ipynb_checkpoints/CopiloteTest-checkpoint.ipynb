# %%
n = int(input("Enter your Number To check that it is Odd/ or EVEN:/")) 
if  n % 2  == 0 :
    print("Even Number: " )
else:
    print("Odd number")
print()
# Out:
# Enter your Number To check that it is Odd/ or EVEN:/ 9
# Odd number

# %%
#- User से age input लीजिए। अगर age 18 या उससे ज़्यादा है तो print करे "Eligible for Voting", वरना "Not Eligible"
age = int(input("Enter you age: To check That you are eligibal to vote or not: /  ")) 

if age >=18:
    print("Your are Eligible To Vote")
else:
    due= 18 -age
    print(f"Your are not eligible to vote waite for the {due} year after you are eligible")
# Out:
# Enter you age: To check That you are eligibal to vote or not: /   16
# Your are not eligible to vote waite for the 2 year after you are eligible

# %%
#- User से कोई number input लीजिए। अगर number positive है तो "Positive", negative है तो "Negative", और अगर 0 है तो "Zero" print करे
numb= int(input("Enter Number to check is it positive or negetive "))
if numb > 0:
    print("Positive Number ")
elif numb < 0 :
    print("Negative Number")
else:
    print("Zero")
# Out:
# Enter Number to check is it positive or negetive  0
# Zero

# %% [markdown]
# #### 2ठीक है Tiwari Ji ✨
# मैं आपको Python में **if-else** के 3 beginner level और 3 intermediate level practice questions दे रहा हूँ।
#
# ---
#
# ## 🟢 Beginner Level (आसान)
# 1. **Odd-Even Check**
#    एक प्रोग्राम लिखिए जो user से कोई number ले और बताए कि वह **even** है या **odd**।
#
# 2. **Age Eligibility**
#    User से age input लीजिए। अगर age 18 या उससे ज़्यादा है तो print करे `"Eligible for Voting"`, वरना `"Not Eligible"`.
#
# 3. **Positive-Negative Check**
#    User से कोई number input लीजिए। अगर number positive है तो `"Positive"`, negative है तो `"Negative"`, और अगर 0 है तो `"Zero"` print करे।
#
# ---
#
# ## 🔵 Intermediate Level (थोड़ा challenging)
# 1. **Grading System**
#    User से marks input लीजिए (0–100)।
#    - अगर marks ≥ 90 → `"Grade A"`
#    - अगर marks ≥ 75 → `"Grade B"`
#    - अगर marks ≥ 50 → `"Grade C"`
#    - वरना `"Fail"`
#
# 2. **Leap Year Check**
#    User से कोई year input लीजिए। अगर year 400 से divisible है या (4 से divisible है और 100 से divisible नहीं है) तो `"Leap Year"` print करे, वरना `"Not Leap Year"`।
#
# 3. **Simple Calculator**
#    User से दो numbers और एक operator (`+`, `-`, `*`, `/`) input लीजिए।
#    - अगर operator `+` है तो addition करे
#    - अगर `-` है तो subtraction करे
#    - अगर `*` है तो multiplication करे
#    - अगर `/` है तो division करे
#    - वरना `"Invalid Operator"` print करे।
#
# ---

# %%
# User से marks input लीजिए (0–100)।

#अगर marks ≥ 90 → "Grade A"
#अगर marks ≥ 75 → "Grade B"
#अगर marks ≥ 50 → "Grade C"
#वरना "Fail"

physics = int(input("Entery Physics Marks"))
chemestry = int(input("Entery Chemestry Marks"))
biology = int(input("Entery Biology Marks"))


total = physics+chemestry+biology

if total > 90: 
    print("Grade A ",total)
elif total > 75:
    print("Grade B ",total)
elif total > 50:
    print("Grade C ",total)
else:
    print("you are Fail")
# Out:
# Entery Physics Marks 12
# Entery Chemestry Marks 12
# Entery Biology Marks 13
# you are Fail

# %%
#User से कोई year input लीजिए। अगर year 400 से divisible है या (4 से divisible है और 100 से divisible नहीं है) तो "Leap Year" print करे, वरना "Not Leap Year"
is_leap= int(input("Enter Value"))

if (is_leap % 400  == 0) or ( is_leap % 4 == 0 and is_leap % 100 != 0):
    print("leap Year")
else:
    print("Not A leap year")
# Out:
# Enter Value 2024
# leap Year

# %%
### **Simple Calculator**  
#   User से दो numbers और एक operator (`+`, `-`, `*`, `/`) input लीजिए।  
#   - अगर operator `+` है तो addition करे  
#  - अगर `-` है तो subtraction करे  
# - अगर `*` है तो multiplication करे  
#   - अगर `/` है तो division करे  
#  - वरना `"Invalid Operator"` print करे। 

a = int(input("Enter First Value "))

b = int(input("Enter 2nd Value "))
output=input("enter operations between +,-,*,/")

if output == '+':
    print(a+b)
elif output == '-':
    print(a-b)
elif output == '*':
    print(a*b)
elif output == '/':
    if b != 0:
        print(a / b)
    else:
        print("Error: Division by zero")
else:
    print("invalid Operation")
# Out:
# Enter First Value  33
# Enter 2nd Value  -3
# enter operations between +,-,*,/ 3
# invalid Operation

# %%
a = int(input("Enter First Value "))

b = int(input("Enter 2nd Value "))
output=input("enter operations between +,-,*,/")

if output == '+':
    print(a+b)
elif output == '-':
    print(a-b)
elif output == '*':
    print(a*b)
elif output == '/':
    if b != 0:
        print(a / b)
    else:
        print("Error: Division by zero")
else:
    print("invalid Operation")
# Out:
# Enter First Value  33
# Enter 2nd Value  -33
# enter operations between +,-,*,/ 3
# invalid Operation
