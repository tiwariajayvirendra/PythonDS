# %%
# - Ek list hai [1, 2, 3, 4, 5].
# Lambda aur map ka use karke har number ka square nikalna hai. Dry run table bhi banao.
nums = [1,2,3,4,5]
add_sq = list(map(lambda x: x * x, nums))
print(add_sq)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 # - Ek list hai [1, 2, 3, 4, 5].
#       2 # Lambda aur map ka use karke har number ka square nikalna hai. Dry run table bhi banao.
#       3 nums = [1,2,3,4,5]
# ----> 4 add_sq = list(map(lambda x: x * x, nums))
#       5 print(add_sq)
#
# TypeError: 'list' object is not callable
