# %%
# Set Data Type  It its Element is add but not change
s = set((43,90,42,23,53,54, 53,43,65,77,86,23,))
s
# Out:
# {23, 42, 43, 53, 54, 65, 77, 86, 90}

# %%
s.add(4)
s
# Out:
# {4, 23, 42, 43, 53, 54, 65, 77, 86, 90}

# %%
s.add(89)
s
# Out:
# {4, 23, 42, 43, 53, 54, 65, 77, 86, 89, 90}

# %%
s.add("rohit")
s
# Out:
# {23, 4, 42, 43, 53, 54, 65, 77, 86, 89, 90, 'rohit'}

# %%
s.add("ajay")
s
# Out:
# {23, 4, 42, 43, 53, 54, 65, 77, 86, 89, 90, 'ajay', 'rohit'}

# %%
s.add("zebra")
s
# Out:
# {23, 4, 42, 43, 53, 54, 65, 77, 86, 89, 90, 'ajay', 'rohit', 'zebra'}

# %%
s.add("ZEBRA")
s
# Out:
# {23, 4, 42, 43, 53, 54, 65, 77, 86, 89, 90, 'ZEBRA', 'ajay', 'rohit', 'zebra'}

# %%
s.add(42.5)
s
# Out:
# {23,
#  4,
#  42,
#  42.5,
#  43,
#  53,
#  54,
#  65,
#  77,
#  86,
#  89,
#  90,
#  'ZEBRA',
#  'ajay',
#  'rohit',
#  'zebra'}

# %%
s.add(8+6j)
s
# Out:
# {(8+6j),
#  23,
#  4,
#  42,
#  42.5,
#  43,
#  53,
#  54,
#  65,
#  77,
#  86,
#  89,
#  90,
#  'ZEBRA',
#  'ajay',
#  'rohit',
#  'zebra'}

# %%
s.add(True)
s
# Out:
# {(8+6j),
#  23,
#  4,
#  42,
#  42.5,
#  43,
#  53,
#  54,
#  65,
#  77,
#  86,
#  89,
#  90,
#  True,
#  'ZEBRA',
#  'ajay',
#  'rohit',
#  'zebra'}

# %%
# single enlement 
s.update(['dhoni'])
s
# Out:
# {(8+6j),
#  23,
#  4,
#  42,
#  42.5,
#  43,
#  53,
#  54,
#  65,
#  77,
#  86,
#  89,
#  90,
#  True,
#  'ZEBRA',
#  'ajay',
#  'dhoni',
#  'rohit',
#  'zebra'}

# %%
s.update(['allen','ALLEN'])
s
# Out:
# {(8+6j),
#  23,
#  4,
#  42,
#  42.5,
#  43,
#  53,
#  54,
#  65,
#  77,
#  86,
#  89,
#  90,
#  'ALLEN',
#  True,
#  'ZEBRA',
#  'ajay',
#  'allen',
#  'dhoni',
#  'rohit',
#  'zebra'}

# %%
s.update("uannu")
s
# Out:
# {(8+6j),
#  12,
#  23,
#  4,
#  42,
#  42.5,
#  43,
#  50,
#  53,
#  54,
#  65,
#  77,
#  86,
#  89,
#  90,
#  98,
#  'ALLEN',
#  'K',
#  'Kannu',
#  True,
#  'ZEBRA',
#  'a',
#  'ajay',
#  'allen',
#  'dhoni',
#  'n',
#  'rohit',
#  'u',
#  'zebra'}

# %%
s.pop()
s
# Out:
# {(8+6j),
#  12,
#  23,
#  4,
#  42,
#  42.5,
#  43,
#  50,
#  53,
#  54,
#  65,
#  77,
#  86,
#  89,
#  90,
#  98,
#  'ALLEN',
#  'Kannu',
#  True,
#  'ZEBRA',
#  'a',
#  'ajay',
#  'allen',
#  'dhoni',
#  'n',
#  'rohit',
#  'u',
#  'zebra'}

# %%
s.pop()
# Out:
# True

# %%
s=[]
type(s)
# Out:
# list

# %%
s.remove("zebra")
s
# Out:
# {(8+6j),
#  12,
#  23,
#  4,
#  42,
#  42.5,
#  43,
#  50,
#  53,
#  54,
#  65,
#  77,
#  86,
#  89,
#  90,
#  98,
#  'ALLEN',
#  'Kannu',
#  'ZEBRA',
#  'a',
#  'ajay',
#  'allen',
#  'dhoni',
#  'n',
#  'rohit',
#  'u'}

# %%
s.clear()
s
# Out:
# set()

# %%
s=()
type(s)
# Out:
# tuple

# %%
s=(3)
type(s)
# Out:
# int

# %%
s=(3,)
type(s)
# Out:
# tuple

# %%
e=(2,4,6,4,8,34,23,64,63,55,77,54}
