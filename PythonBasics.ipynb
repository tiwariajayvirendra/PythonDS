# %%
#wap to know that the number is spy or not and and if it is equal to product then it is called spy number 

num = int(input("Enter Your Number: "))

sum = 0
prod = 1

while num >0:
    rem=num % 10
    sum=sum+rem
    prod=prod*rem
    num =num // 10
if sum == prod:
    print("Spy")
else:
    print("Not")
# Out:
# Enter Your Number:  123
# Spy

# %%
#Wap to check any number is perfect number or not ;

num = int(input("enter To check factor "))
sum = 0 
while i > num:
    rem =num%10 
    sum=sum+rem
    if i == num:
        print("Perfect")
    else:
        print("Not Perfect")
# Out:
#   Cell In[8], line 6
#     rem =num%10=0
#          ^
# SyntaxError: cannot assign to expression

# %%
num = int(input("enter to check Perfect Number:"))
sum = 0
for i in range (1,num//2+1):
    if n%i == 0:
        sum=sum+i
if sum == n:
    print("Perfect")
else:
    print("not perfect")
# Out:
# enter to check Perfect Number: 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2 sum = 0
#       3 for i in range (1,num//2+1):
# ----> 4     if n%i == 0:
#       5         sum=sum+i
#       6 if sum == n:
#
# NameError: name 'n' is not defined

# %%
#wap to print Armstron Number or not 

num = int(input("enter your number"))
armstrong = str(num)
n = len(armstrong)

SumOfPower = 0
for a in armstrong:
    sumOfPower += int(a)**n
if sumOfPower == num:
    print("Is an Armstong Number")
else:
    print("Not a Armstrong Number")
# Out:
# enter your number 123
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 9
#       7 SumOfPower = 0
#       8 for a in armstrong:
# ----> 9     sumOfPower += int(a)**n
#      10 if sumOfPower == num:
#      11     print("Is an Armstong Number")
#
# NameError: name 'sumOfPower' is not defined

# %%
n=int(input("enter ay Num"))
a = n
count = 0
while n>0:
    count=count+1
    n=n//10
n=a
sum=0
while n>0:
    rem=n%10
    sum =sum+rem**count
    n=n//10
if sum  == a :
    print("armstrong")
else:
    print("Not")
# Out:
# enter ay Num 123
# Number

# %%
#Patterns In star 
n = int(input("ENter no of Rows"))
for i in range (1,n+1):
    print("*"*i);
# Out:
# ENter no of Rows 5
# *
# **
# ***
# ****
# *****

# %%
n = int(input("ENter no of Rows"))
for i in range (1,n+1):
    print("*"*(n-i),)
# Out:
# ENter no of Rows 5
# **** *** ** *

# %%
n = int(input("Enter Your Star number"))
for i in range (1,n+1):
        for j in range(n-i):
             print(" ",end=" ")
        
        for k in range(2*i-1):
            print("*",end=" ")
        print()
  
for i in range (n,1):
    for j in range(1,n+1):
        for k in range(1,):
            print("*", end=" ")
        print()
# Out:
# Enter Your Star number 5
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *

# %%
n = int(input("enter Number"))
#upper Pyramid
for i in range (1, n+1):
    print(" "*(n-i)+"* "*(i))
for i in range(n-1,0,-1):
    print(" "*(n-i)+"* \"*(i))
# Out:
# enter Number 5
#     *
#    * *
#   * * *
#  * * * *
# * * * * *
#  * * * *
#   * * *
#    * *
#     *

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(7)
# Out:
# 7

# %%
print(5.6)
# Out:
# 5.6

# %%
print("India","Pakistan","Nepal","Srilanka")
# Out:
# India Pakistan Nepal Srilanka

# %%
print("India","Pakistan","Nepal","Srilanka",sep='/')
# Out:
# India/Pakistan/Nepal/Srilanka

# %%
print("hello")
print("World")
# Out:
# hello
# World

# %%
print("Hello", end=' ')
print("World")
# Out:
# Hello World

# %%
print(1.7e308)
# Out:
# 1.7e+308

# %%
#Complex
print(4+5j)
# Out:
# (4+5j)

# %%
#string
print('Kolkata')
print("Kolkata")
print("""Kolkata""")
# Out:
# Kolkata
# Kolkata
# Kolkata

# %%
#List 
print([1,3,4,6,7])
# Out:
# [1, 3, 4, 6, 7]

# %%
#Tuple
print((1,3,4,5,6))
# Out:
# (1, 3, 4, 5, 6)

# %%
#Sets
print({1,3,4,5,2,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#Dict
print({"Name": "Nitish", "Age":30,"gender":"male"})
# Out:
# {'Name': 'Nitish', 'Age': 30, 'gender': 'male'}

# %%
name ="Ajay"

print(name)
# Out:
# Ajay

# %%
#Hynaminc Binding

# %%
#Static Binding

# %%
# Spacial Syntax
a =5; b= 6; c=8
print(a)
print(b)
print(c)
# Out:
# 5
# 6
# 8

# %%
#Declaration Technique
a,b,c = 4,5,6
print(a)
print(b)
print(c)
a = b = c  = 6
print(a)
print(b)
print(c)
# Out:
# 4
# 5
# 6
# 6
# 6
# 6

# %%
#Idetifiers and Keywords

# %%
#Python has 33 Keywords  
#Do not Use these word to declare in variable it will cause some problems 
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#Python Identifiers
#A python identifiers is a name used to identify a variable , fucntion , class, module or other object ,
__= 'ajay'
print(__)
# Out:
# ajay

# %%
#USER input  in this we will take Input Form USER / 
#Exanple = Softer is talking to you but you don't 
#IN dynaminc software -   In this will talk with software and software is with us for example like Youtube While we will search it we will get our answer google is also a exmaple , so we have one system like 
#input
input("Apna Nam Bata")
# Out:
# Apna Nam Bata Ajay
# 'Ajay'

# %%
first_num= input("Enter The First Number")
second_num= input("Enter the second Number")
# Out:
# Enter The First Number 40
# Enter the second Number 60

# %%
print(first_num)
print(second_num)
# Out:
# 40
# 60

# %%
result = int(first_num )+int(second_num)
print(result)
# Out:
# 100

# %%
#Type function to know what is the data type of the variable .
type([1,3,4,6])
# Out:
# list

# %%
type(first_num)
# Out:
# str

# %%
#Type Conversion Data Type it has Two Types 
#Implicit

#Explicit

# %%
result = int(first_num )+int(second_num)
print(result)

# %%
#Implicit
4+5.5
# Out:
# 9.5

# %%
#Explicit 
#int
first_num + second_num
# Out:
# '4060'

# %%
complex(4)
# Out:
# (4+0j)

# %%
list('hello')
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
int('Hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 int('Hello')
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %%
a = 4.5
int(a)
# Out:
# 4

# %%
a
# Out:
# 4.5

# %%
first_num= int(input("Enter The First Number"))
second_num= int(input("Enter the second Number"))

result = first_num + second_num
print(result) #Testing
# Out:
# Enter The First Number 50
# Enter the second Number 51
# 101

# %%
#Template Litrals / AND Operators /
