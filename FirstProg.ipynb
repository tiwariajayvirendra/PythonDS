# %%
#wap to print addition of three numbers 

a = input("Enter any num")
b = input("Enter any num")
c = input("Enter any num")
sum = a+b+c
print(f"sum of three number is {sum}")
# Out:
# Enter any num 2
# Enter any num 3
# Enter any num 4
# sum of three number is 234

# %%
#wap to print sum of first two number's and avg of last two number form three numbers.
a = int(input("Enter any num"))
b = int(input("Enter any num"))
c = int(input("Enter any num"))
sum = a+b
avg =(b+c)/2
print(f'sum of first two number is {sum} and also {avg}')
# Out:
# Enter any num 10
# Enter any num 20
# Enter any num 5
# sum of first two number is 30 and also 12.5

# %%
#Wap to print first characer middle character and last character of ur name after reversing
a = "Ajay_Tiwari"
b={}
a[::-1]
b=a[:5:-11]
b
# Out:
# 'i'

# %%
name = input("enter your name ")
rev = name[::-1]
firstch=rev[0]
centrech=rev[len(rev)//2]
lastch=rev[-1]
print(f"after reversing my name is {rev}, then its first ch {firstch} its centere cha {centrech}and {lastch}")
# Out:
# enter your name  Ajay_tiwari
# after reversing my name is irawit_yajA, then its first ch i its centere cha tand A

# %%
#wap to print sum of first ch, centre ch and last ch of a number stored in a string

num = input("Enter a number: ")
first = int(num_str[0])
centre = int(num_str[len(num_str) // 2])
last = int(num_str[-1])
total = first + centre + last
print("Number:", num_str)
print("First:", first, "Centre:", centre, "Last:", last)
print("Sum:", total)
# Out:
# Enter a number:  9865432109
# Number: 9865432109
# First: 9 Centre: 3 Last: 9
# Sum: 21

# %%
num = input("Enter a number:")
first = int(num[0])
center = int(num[len(num)//2])
last = int(num[-1])
total = first+ center + last
print( "Nnumber:",num)
print( "First:", first, "Centre:", center,"Last:", last)
print( "Sum:", total)
# Out:
# Enter a number: 989803994
# Nnumber: 989803994
# First: 9 Centre: 0 Last: 4
# Sum: 13

# %%
a = int(input("Enter value of side of sq in m"))
area = a*a
peri=4*a
diag=(2**0.5)*a
print("area:",area,"Per",peri,"Dig",diag)
# Out:
# Enter value of side of sq in m 25
# area: 625 Per 100 Dig 35.35533905932738
