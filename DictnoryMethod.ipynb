# %%
students = {"Aman": 85, "Riya": 92, "Karan": 78, "Meena": 88, "Tiwari": 95}
students["Meena"]
# Out:
# 88

# %%
a = 663
b = 261

a & b
# Out:
# 5

# %%
a | b
# Out:
# 919

# %%
a ^ b
# Out:
# 914

# %%
i = 1273
j = 1413

i ^ j
# Out:
# 380

# %%
i ^ j
# Out:
# 380

# %%
k = 999
l = 729
k ^ l
# Out:
# 318

# %%
amount=int(input("enter ur amount"))
product=input("enter ur product as gold/silver/others")
payment=input("enter payment mode as online /offline")
discount=0

if amount>50000:
    if product=="gold":
        discount=0.10
    elif product=="silver":
        discount=0.05
    else:
        discount=0.02
else:
    if product=="gold":
        discount=0.10
    else:
        discount=0
total_amount=amount-(amount*discount)
print(total_amount)

if payment=="online":
    final_amount=total_amount-(total_amount*0.01)
    print(final_amount)
else:
    print(total_amount)
# Out:
# enter ur amount 100000
# enter ur product as gold/silver/others gold
# enter payment mode as online /offline online
# 90000.0
# 89100.0

# %%
#wap to print diff types of triangle on the basis of its sides

# %%
a=int(input("Enter you triangel Length  value A : "))
b=int(input("Enter You Triangle breath value B: "))
c=int(input("Enter Your Triangel Perpendicular value or Height C : "))

if a+b>c and b+c>a and c+a>b:
    print("Print First value")
    if a==b==c:
        print("Equeletral triangle")
    elif a!=b!=c:
        print("Scalian Triangle")
    else:
        print("Print Isocelious Triangle")
else:
    print("Triangle wont Be formed")
# Out:
# Enter you triangel Length  value A :  5
# Enter You Triangle breath value B:  10
# Enter Your Triangel Perpendicular value or Height C :  12
# Print First value
# Scalian Triangle

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 if a+b>c and b+c>a and c+a>b:
#       2     print("Print First value")
#       3     if a==b==c:
#
# NameError: name 'a' is not defined
